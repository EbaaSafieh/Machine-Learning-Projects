# %%
import pandas as pd
import numpy as np

df = pd.read_csv('kc_house_data.csv')

y=df['price']

df = df.drop('id', axis=1)
df = df.drop('date', axis=1)

X = df.loc[:, df.columns != 'price']

# %%
X.isnull().sum()
# Out:
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# 1               0     0          3      7        2170            400
# 2               0     0          3      6         770              0
# 3               0     0          5      7        1050            910
# 4               0     0          3      8        1680              0
# ...           ...   ...        ...    ...         ...            ...
# 21608           0     0          3      8        1530              0
# 21609           0     0          3      8        2310              0
# 21610           0     0          3      7        1020              0
# 21611           0     0          3      8        1600              0
# 21612           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1955             0    98178  47.5112 -122.257           1340
# 1          1951          1991    98125  47.7210 -122.319           1690
# 2          1933             0    98028  47.7379 -122.233           2720
# 3          1965             0    98136  47.5208 -122.393           1360
# 4          1987             0    98074  47.6168 -122.045           1800
# ...         ...           ...      ...      ...      ...            ...
# 21608      2009             0    98103  47.6993 -122.346           1530
# 21609      2014             0    98146  47.5107 -122.362           1830
# 21610      2009             0    98144  47.5944 -122.299           1020
# 21611      2004             0    98027  47.5345 -122.069           1410
# 21612      2008             0    98144  47.5941 -122.299           1020
#
#        sqft_lot15
# 0            5650
# 1            7639
# 2            8062
# 3            5000
# 4            7503
# ...           ...
# 21608        1509
# 21609        7200
# 21610        2007
# 21611        1287
# 21612        1357
#
# [21613 rows x 19 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
LinearRegression_modle = LinearRegression()

LinearRegression_modle.fit(X_train,y_train)

print('linear model coeff (w)', LinearRegression_modle.coef_)
print('linear model intercept (b)' , LinearRegression_modle.intercept_)
print('R-squared score (training)', LinearRegression_modle.score(X_train, y_train))
print('R-squared score (test)', LinearRegression_modle.score(X_test,y_test))
# Out:
# linear model coeff (w) [-3.69091640e+04  4.34170471e+04  1.12834884e+02  1.43589827e-01
#   3.72659266e+03  5.62221052e+05  5.37902167e+04  2.58306532e+04
#   9.76203616e+04  7.26435597e+01  4.01913245e+01 -2.62621112e+03
#   1.93749062e+01 -6.01588774e+02  5.99025946e+05 -2.24360185e+05
#   1.71593506e+01 -4.18219836e-01]
# linear model intercept (b) 7575764.174487669
# R-squared score (training) 0.6971880634365921
# R-squared score (test) 0.7109247568849111

# %%
from sklearn.linear_model import Lasso

lasso_model = Lasso(alpha=2.0, max_iter = 10000).fit(X_train, y_train)

print('lasso regression linear model intercept: {}'
     .format(lasso_model.intercept_))
print('lasso regression linear model coeff:\n{}'
     .format(lasso_model.coef_))
print('Non-zero features: {}'
     .format(np.sum(lasso_model.coef_ != 0)))
print('R-squared score (training): {:.3f}'
     .format(lasso_model.score(X_train, y_train)))
print('R-squared score (test): {:.3f}\n'
     .format(lasso_model.score(X_test, y_test)))
# Out:
# lasso regression linear model intercept: 7576940.606997874
# lasso regression linear model coeff:
# [-3.69067640e+04  4.34102521e+04  2.90165914e+02  1.43519252e-01
#   3.72438788e+03  5.61934561e+05  5.38009569e+04  2.58239559e+04
#   9.76256319e+04 -1.04686434e+02 -1.37129518e+02 -2.62646887e+03
#   1.93766823e+01 -6.01304183e+02  5.98894735e+05 -2.24177402e+05
#   1.71532667e+01 -4.18344572e-01]
# Non-zero features: 18
# R-squared score (training): 0.697
# R-squared score (test): 0.711
# C:\Users\ebaa0\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.314e+14, tolerance: 2.418e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
from sklearn.linear_model import Lasso

lasso_model_0 = Lasso(alpha=0.0, max_iter = 500).fit(X_train, y_train)

print('lasso regression linear model intercept: {}'
     .format(lasso_model_0.intercept_))
print('lasso regression linear model coeff:\n{}'
     .format(lasso_model_0.coef_))
print('Non-zero features: {}'
     .format(np.sum(lasso_model_0.coef_ != 0)))
print('R-squared score (training): {:.3f}'
     .format(lasso_model_0.score(X_train, y_train)))
print('R-squared score (test): {:.3f}\n'
     .format(lasso_model_0.score(X_test, y_test)))
# Out:
# lasso regression linear model intercept: 7575764.174493115
# lasso regression linear model coeff:
# [-3.69091640e+04  4.34170471e+04  2.90227419e+02  1.43589827e-01
#   3.72659266e+03  5.62221052e+05  5.37902167e+04  2.58306532e+04
#   9.76203616e+04 -1.04748975e+02 -1.37201210e+02 -2.62621112e+03
#   1.93749062e+01 -6.01588774e+02  5.99025946e+05 -2.24360185e+05
#   1.71593506e+01 -4.18219836e-01]
# Non-zero features: 18
# R-squared score (training): 0.697
# R-squared score (test): 0.711
# C:\Users\ebaa0\AppData\Local\Temp\ipykernel_12844\2395177355.py:3: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   lasso_model_0 = Lasso(alpha=0.0, max_iter = 500).fit(X_train, y_train)
# C:\Users\ebaa0\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\ebaa0\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.661e+14, tolerance: 2.418e+11 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(

# %%
from sklearn.linear_model import Lasso

lasso_model_0 = Lasso(alpha=1.0, max_iter = 5000).fit(X_train, y_train)

print('lasso regression linear model intercept: {}'
     .format(lasso_model_0.intercept_))
print('lasso regression linear model coeff:\n{}'
     .format(lasso_model_0.coef_))
print('Non-zero features: {}'
     .format(np.sum(lasso_model_0.coef_ != 0)))
print('R-squared score (training): {:.3f}'
     .format(lasso_model_0.score(X_train, y_train)))
print('R-squared score (test): {:.3f}\n'
     .format(lasso_model_0.score(X_test, y_test)))
# Out:
# lasso regression linear model intercept: 7576352.390746314
# lasso regression linear model coeff:
# [-3.69079640e+04  4.34136496e+04  2.90213857e+02  1.43554539e-01
#   3.72549027e+03  5.62077807e+05  5.37955868e+04  2.58273046e+04
#   9.76229967e+04 -1.04734895e+02 -1.37182555e+02 -2.62634000e+03
#   1.93757942e+01 -6.01446479e+02  5.98960341e+05 -2.24268794e+05
#   1.71563086e+01 -4.18282204e-01]
# Non-zero features: 18
# R-squared score (training): 0.697
# R-squared score (test): 0.711
# C:\Users\ebaa0\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.314e+14, tolerance: 2.418e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model=RandomForestRegressor(n_estimators=50)
rf_model.fit(X_train, y_train)
print('R-squared score (test): {:.3f}\n'
     .format(rf_model.score(X_test, y_test)))
# Out:
# R-squared score (test): 0.889

# %%
rf_model1=RandomForestRegressor(n_estimators=200)
rf_model1.fit(X_train, y_train)
print('R-squared score (test): {:.3f}\n'
     .format(rf_model1.score(X_test, y_test)))
# Out:
# R-squared score (test): 0.890

# %%
rf_model1=RandomForestRegressor(n_estimators=50,max_features=16,max_depth=20,)
rf_model1.fit(X_train, y_train)
print('R-squared score (test): {:.3f}\n'
     .format(rf_model1.score(X_test, y_test)))
# Out:
# R-squared score (test): 0.885

# %%
rf_model1=RandomForestRegressor(n_estimators=50,max_features=4,min_samples_split=3)
rf_model1.fit(X_train, y_train)
print('R-squared score (test): {:.3f}\n'
     .format(rf_model1.score(X_test, y_test)))
# Out:
# R-squared score (test): 0.875
